# %% [markdown]
# # Querying [tmdb](https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata) movie information from aperturedb.
#
# This notebook will work on an instance of ApertureDB, which can be on the [cloud](https://cloud.aperturedata.io), or running as a [local docker container(s)](https://docs.aperturedata.io/Setup/server/Local)
#
# The dataset is hosted on kaggle, and available via a mlcroissant link.

# %%
# %pip install --quiet mlcroissant pandas dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import all the modules needed

# %%
import pandas as pd
from IPython.display import display


from aperturedb.CommonLibrary import (
    execute_query,
    create_connector
)
from aperturedb.Utils import Utils

# %%
client=create_connector()
utils = Utils(client)
utils.summary()
# Out:
# ================== Summary ==================
# Database: localhost
# Version: 0.18.10
# Status:  0
# Info:    OK
# ------------------ Entities -----------------
# Total entities types:    6
# GENRE
#   Total elements: 20
# I   Number   | id     |        20 (100%)
#     String   | label  |        20 (100%)
#     String   | name   |        20 (100%)
# KEYWORD
#   Total elements: 9813
# I   Number   | id     |      9813 (100%)
#     String   | label  |      9813 (100%)
#     String   | name   |      9813 (100%)
# MOVIE
#   Total elements: 4803
#     Number   | budget        |      4803 (100%)
# I   String   | id            |      4803 (100%)
#     String   | label         |      4803 (100%)
#   ! Number   | movie_id      |      4803 (100%)
#     String   | name          |      4803 (100%)
#     String   | overview      |      4803 (100%)
#     Number   | popularity    |      4803 (100%)
#     String   | tagline       |      4803 (100%)
#     String   | title         |      4803 (100%)
#     Number   | vote_average  |      4803 (100%)
#     Number   | vote_count    |      4803 (100%)
# PRODUCTION_COMPANY
#   Total elements: 5047
# I   Number   | id     |      5047 (100%)
#     String   | label  |      5047 (100%)
#     String   | name   |      5047 (100%)
# PROFESSIONAL
#   Total elements: 104842
#     Number   | gender  |    104842 (100%)
# I   Number   | id      |    104842 (100%)
#     String   | label   |    104842 (100%)
#     String   | name    |    104842 (100%)
# SPOKEN_LANGUAGE
#   Total elements: 87
# I   String   | iso_639_1  |        87 (100%)
#     String   | label      |        87 (100%)
#     String   | name       |        87 (100%)
# ---------------- Connections ----------------
# Total connections types: 6
# CAST
#   MOVIE ====> PROFESSIONAL
#   Total elements: 106257
# I   Number   | cast_id    |    106257 (100%)
#     String   | character  |    106257 (100%)
#     String   | name       |    106257 (100%)
# CREW
#   MOVIE ====> PROFESSIONAL
#   Total elements: 129581
#   ! String   | credit_id   |    129581 (100%)
#     String   | department  |    129581 (100%)
#     String   | job         |    129581 (100%)
#     String   | name        |    129581 (100%)
# HAS_GENRE
#   MOVIE ====> GENRE
#   Total elements: 12160
#     String   | name  |     12160 (100%)
# HAS_KEYWORD
#   MOVIE ====> KEYWORD
#   Total elements: 36194
#     String   | name  |     36194 (100%)
# HAS_PRODUCTION_COMPANY
#   MOVIE ====> PRODUCTION_COMPANY
#   Total elements: 13677
#     String   | name  |     13677 (100%)
# HAS_SPOKEN_LANGUAGE
#   MOVIE ====> SPOKEN_LANGUAGE
#   Total elements: 6937
#     String   | name  |      6937 (100%)
# ------------------ Totals -------------------
# Total nodes: 124612
# Total edges: 304806
# =============================================

# %% [markdown]
# ## Query time!
# ### Find all the movies where Tom Hanks as been a part of

# %%
q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints": {
                "name": ["==", "Tom hanks"]
            },
            "results": {
                "all_properties": True
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "is_connected_to": {
                "ref": 1
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"]
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

display(pd.json_normalize(response[0]["FindEntity"]["entities"]))
display(pd.json_normalize(response[1]["FindEntity"]["entities"]))

movie_ids = [e["movie_id"] for e in response[1]["FindEntity"]["entities"]]
display(movie_ids)
# Out:
#         _uniqueid  gender  id         label       name
# 0  33.1648.483960       2  31  PROFESSIONAL  Tom hanks
#          _uniqueid     budget      id  label  movie_id  \
# 0     32.29.483960   40000000   64685  MOVIE     64685
# 1    32.379.483966   26000000    9800  MOVIE      9800
# 2    32.642.483972  200000000   10193  MOVIE     10193
# 3    32.673.483972  175000000    2698  MOVIE      2698
# 4    32.690.483972  165000000    5255  MOVIE      5255
# 5    32.727.483974   70000000     857  MOVIE       857
# 6    32.734.483974   52000000     568  MOVIE       568
# 7    32.737.483974   65000000    9489  MOVIE      9489
# 8    32.789.483974   60000000     497  MOVIE       497
# 9    32.820.483976   55000000   13600  MOVIE     13600
# 10   32.884.483976   35000000  140823  MOVIE    140823
# 11   32.895.483976          0    5516  MOVIE      5516
# 12  32.1059.483980    1000000   13508  MOVIE     13508
# 13  32.1428.483988  150000000   13448  MOVIE     13448
# 14  32.1653.483992   35000000   20763  MOVIE     20763
# 15  32.2032.484000    8000000    2619  MOVIE      2619
# 16  32.2201.484004  125000000     591  MOVIE       591
# 17  32.2293.484004  100000000   16523  MOVIE     16523
# 18  32.2308.484006   55000000      13  MOVIE        13
# 19  32.2317.484006   55000000  109424  MOVIE    109424
# 20  32.2382.484006   52000000     640  MOVIE       640
# 21  32.2385.484006   52000000   11631  MOVIE     11631
# 22  32.2439.484008   30000000     862  MOVIE       862
# 23  32.3001.484020  102000000   83542  MOVIE     83542
# 24  32.3043.484020   90000000     863  MOVIE       863
# 25  32.3084.484020   90000000    8358  MOVIE      8358
# 26  32.3210.484024   30000000   59861  MOVIE     59861
# 27  32.3304.484026          0    9591  MOVIE      9591
# 28  32.3844.484036   80000000    4147  MOVIE      4147
# 29  32.3977.484038   50000000    9906  MOVIE      9906
# 30  32.4484.484048    5000000    8346  MOVIE      8346
# 31  32.4507.484050   18000000    2280  MOVIE      2280
# 32  32.4518.484050   18000000  302688  MOVIE    302688
# 33  32.4617.484052   60000000     594  MOVIE       594
# 34  32.4620.484052   75000000    6538  MOVIE      6538
# 35  32.4654.484052   75000000      35  MOVIE        35
# 36  32.4662.484052  120000000     920  MOVIE       920
# 37  32.4754.484054   40000000   11287  MOVIE     11287
# 38  32.4782.484054   40000000  296098  MOVIE    296098
#
#                                  name  \
# 0   Extremely loud & incredibly close
# 1                        Philadelphia
# 2                         Toy story 3
# 3                       Evan almighty
# 4                   The polar express
# 5                 Saving private ryan
# 6                           Apollo 13
# 7                     You've got mail
# 8                      The green mile
# 9                       City of ember
# 10                   Saving mr. banks
# 11                    The ladykillers
# 12       Who killed the electric car?
# 13                    Angels & demons
# 14                        Radio flyer
# 15                             Splash
# 16                  The da vinci code
# 17          Where the wild things are
# 18                       Forrest gump
# 19                   Captain phillips
# 20                Catch me if you can
# 21                         Mamma mia!
# 22                          Toy story
# 27  In every life there comes a time when that dre...
# 28                         Pray for Michael Sullivan.
# 29                     The battle for the lawn is on.
# 30          Love is here to stay... so is her family.
# 31  You're Only Young Once But For Josh It Might J...
# 32                       People change. Greeks don't.
# 33                                   Life is waiting.
# 34  Based on a true story. You think we could make...
# 35       See our family. And feel better about yours.
# 36             Ahhh... it's got that new movie smell.
# 37  To achieve the incredible, you have to attempt...
# 38  In the shadow of war, one man showed the world...
#
#                                 title  vote_average  vote_count
# 0   Extremely Loud & Incredibly Close           6.9         708
# 1                        Philadelphia           7.6         988
# 2                         Toy Story 3           7.6        4597
# 3                       Evan Almighty           5.3        1151
# 4                   The Polar Express           6.4        1474
# 5                 Saving Private Ryan           7.9        5048
# 6                           Apollo 13           7.3        1599
# 7                     You've Got Mail           6.3         838
# 8                      The Green Mile           8.2        4048
# 9                       City of Ember           6.2         605
# 10                   Saving Mr. Banks           7.3        1226
# 11                    The Ladykillers           6.0         415
# 12       Who Killed the Electric Car?           7.2          59
# 13                    Angels & Demons           6.5        2129
# 14                        Radio Flyer           6.6          53
# 15                             Splash           6.1         321
# 16                  The Da Vinci Code           6.5        2704
# 17          Where the Wild Things Are           6.4         572
# 18                       Forrest Gump           8.2        7927
# 19                   Captain Phillips           7.6        2454
# 20                Catch Me If You Can           7.7        3795
# 21                         Mamma Mia!           6.4        1386
# 22                          Toy Story           7.7        5269
# 23                        Cloud Atlas           6.6        2977
# 24                        Toy Story 2           7.3        3806
# 25                          Cast Away           7.5        3218
# 26                       Larry Crowne           5.7         359
# 27                 That Thing You Do!           6.8         225
# 28                  Road to Perdition           7.3        1077
# 29                      The Ant Bully           5.5         366
# 30           My Big Fat Greek Wedding           6.2         671
# 31                                Big           6.9         993
# 32         My Big Fat Greek Wedding 2           5.5         322
# 33                       The Terminal           7.0        1910
# 34               Charlie Wilson's War           6.5         338
# 35                 The Simpsons Movie           6.9        2264
# 36                               Cars           6.6        3877
# 37              A League of Their Own           6.7         354
# 38                    Bridge of Spies           7.2        2583
# [64685,
#  9800,
#  10193,
#  2698,
#  5255,
#  857,
#  568,
#  9489,
#  497,
#  13600,
#  140823,
#  5516,
#  13508,
#  13448,
#  20763,
#  2619,
#  591,
#  16523,
#  13,
#  109424,
#  640,
#  11631,
#  862,
#  83542,
#  863,
#  8358,
#  59861,
#  9591,
#  4147,
#  9906,
#  8346,
#  2280,
#  302688,
#  594,
#  6538,
#  35,
#  920,
#  11287,
#  296098]

# %% [markdown]
# ### Get more info.
#
# This response from cast and movies entities still misses the character information, because it's been encoded on the properties on connection between the 2. Let's merge that info in and get more richer details about the movies Tom Hanks has been a part of.

# %%
professional = pd.json_normalize(response[1]["FindEntity"]["entities"])

professional_details = []
for p in response[0]["FindEntity"]["entities"]:
    src = p["_uniqueid"]
    for m in response[1]["FindEntity"]["entities"]:
        dst = m["_uniqueid"]
        q = [{
            "FindEntity": {
                "_ref": 1,
                "with_class": "PROFESSIONAL",
                "constraints": {
                    "_uniqueid": ["==", src]
                },
                "results": {
                    "all_properties": True
                }
            }
        },
        {
            "FindEntity": {
                "_ref": 2,
                "is_connected_to": {
                    "ref": 1
                },
                "with_class": "MOVIE",
                "constraints": {
                    "_uniqueid": ["==", dst]
                },
                "results": {
                    "all_properties": True
                }
            }
        },{
            "FindConnection": {
                "src": 2,
                "dst": 1,
                "results": {
                    "all_properties": True
                }
            }
        }]
        _, responsec, _ = execute_query(client, q)
        # print(f"{response=}")

        if responsec[2]["FindConnection"]["returned"] > 0:
            c = responsec[2]["FindConnection"]["connections"][0]
            # print(f"{p['name']} has acted in {m['title']} as {c['character']}")
            # print(f"{p['name']} has contributed in {m['title']}")
            if "character" in c:
                professional_details.append(f"as character: {c['character']}")
            else:
                professional_details.append(f"as {c['job']} in {c['department']}")
            # display(pd.json_normalize(response[3]["FindConnection"]["connections"]))
display(len(professional_details))
professional['details'] = professional_details

display(professional)
# Out:
# 39
#          _uniqueid     budget      id  label  movie_id  \
# 0     32.29.483960   40000000   64685  MOVIE     64685
# 1    32.379.483966   26000000    9800  MOVIE      9800
# 2    32.642.483972  200000000   10193  MOVIE     10193
# 3    32.673.483972  175000000    2698  MOVIE      2698
# 4    32.690.483972  165000000    5255  MOVIE      5255
# 5    32.727.483974   70000000     857  MOVIE       857
# 6    32.734.483974   52000000     568  MOVIE       568
# 7    32.737.483974   65000000    9489  MOVIE      9489
# 8    32.789.483974   60000000     497  MOVIE       497
# 9    32.820.483976   55000000   13600  MOVIE     13600
# 10   32.884.483976   35000000  140823  MOVIE    140823
# 11   32.895.483976          0    5516  MOVIE      5516
# 12  32.1059.483980    1000000   13508  MOVIE     13508
# 13  32.1428.483988  150000000   13448  MOVIE     13448
# 14  32.1653.483992   35000000   20763  MOVIE     20763
# 15  32.2032.484000    8000000    2619  MOVIE      2619
# 16  32.2201.484004  125000000     591  MOVIE       591
# 17  32.2293.484004  100000000   16523  MOVIE     16523
# 18  32.2308.484006   55000000      13  MOVIE        13
# 19  32.2317.484006   55000000  109424  MOVIE    109424
# 20  32.2382.484006   52000000     640  MOVIE       640
# 21  32.2385.484006   52000000   11631  MOVIE     11631
# 22  32.2439.484008   30000000     862  MOVIE       862
# 23  32.3001.484020  102000000   83542  MOVIE     83542
# 24  32.3043.484020   90000000     863  MOVIE       863
# 25  32.3084.484020   90000000    8358  MOVIE      8358
# 26  32.3210.484024   30000000   59861  MOVIE     59861
# 27  32.3304.484026          0    9591  MOVIE      9591
# 28  32.3844.484036   80000000    4147  MOVIE      4147
# 29  32.3977.484038   50000000    9906  MOVIE      9906
# 30  32.4484.484048    5000000    8346  MOVIE      8346
# 31  32.4507.484050   18000000    2280  MOVIE      2280
# 32  32.4518.484050   18000000  302688  MOVIE    302688
# 33  32.4617.484052   60000000     594  MOVIE       594
# 34  32.4620.484052   75000000    6538  MOVIE      6538
# 35  32.4654.484052   75000000      35  MOVIE        35
# 36  32.4662.484052  120000000     920  MOVIE       920
# 37  32.4754.484054   40000000   11287  MOVIE     11287
# 38  32.4782.484054   40000000  296098  MOVIE    296098
#
#                                  name  \
# 0   Extremely loud & incredibly close
# 1                        Philadelphia
# 2                         Toy story 3
# 3                       Evan almighty
# 4                   The polar express
# 14                            Powered by imagination.
# 15  Allen Bauer Thought He'd Never Find The Right ...
# 16                                    Seek the truth.
# 17                          There's one in all of us.
# 18  The world will never be the same, once you've ...
# 19                   Out here survival is everything.
# 20                     The true story of a real fake.
# 21     Take a trip down the aisle you'll never forget
# 22                                               None
# 23                            Everything is Connected
# 24                                 The toys are back!
# 25      At the edge of the world, his journey begins.
# 26                           Rediscover life and love
# 27  In every life there comes a time when that dre...
# 28                         Pray for Michael Sullivan.
# 29                     The battle for the lawn is on.
# 30          Love is here to stay... so is her family.
# 31  You're Only Young Once But For Josh It Might J...
# 32                       People change. Greeks don't.
# 33                                   Life is waiting.
# 34  Based on a true story. You think we could make...
# 35       See our family. And feel better about yours.
# 36             Ahhh... it's got that new movie smell.
# 37  To achieve the incredible, you have to attempt...
# 38  In the shadow of war, one man showed the world...
#
#                                 title  vote_average  vote_count  \
# 0   Extremely Loud & Incredibly Close           6.9         708
# 1                        Philadelphia           7.6         988
# 2                         Toy Story 3           7.6        4597
# 3                       Evan Almighty           5.3        1151
# 4                   The Polar Express           6.4        1474
# 5                 Saving Private Ryan           7.9        5048
# 6                           Apollo 13           7.3        1599
# 7                     You've Got Mail           6.3         838
# 8                      The Green Mile           8.2        4048
# 9                       City of Ember           6.2         605
# 10                   Saving Mr. Banks           7.3        1226
# 11                    The Ladykillers           6.0         415
# 12       Who Killed the Electric Car?           7.2          59
# 13                    Angels & Demons           6.5        2129
# 14                        Radio Flyer           6.6          53
# 15                             Splash           6.1         321
# 16                  The Da Vinci Code           6.5        2704
# 17          Where the Wild Things Are           6.4         572
# 18                       Forrest Gump           8.2        7927
# 19                   Captain Phillips           7.6        2454
# 20                Catch Me If You Can           7.7        3795
# 21                         Mamma Mia!           6.4        1386
# 22                          Toy Story           7.7        5269
# 23                        Cloud Atlas           6.6        2977
# 24                        Toy Story 2           7.3        3806
# 25                          Cast Away           7.5        3218
# 26                       Larry Crowne           5.7         359
# 27                 That Thing You Do!           6.8         225
# 28                  Road to Perdition           7.3        1077
# 29                      The Ant Bully           5.5         366
# 30           My Big Fat Greek Wedding           6.2         671
# 31                                Big           6.9         993
# 32         My Big Fat Greek Wedding 2           5.5         322
# 33                       The Terminal           7.0        1910
# 34               Charlie Wilson's War           6.5         338
# 35                 The Simpsons Movie           6.9        2264
# 36                               Cars           6.6        3877
# 37              A League of Their Own           6.7         354
# 38                    Bridge of Spies           7.2        2583
#
#                                               details
# 0                         as character: Thomas Schell
# 1                        as character: Andrew Beckett
# 2                         as character: Woody (voice)
# 3                 as Executive Producer in Production
# 4   as character: Hero Boy / Father / Conductor / ...
# 5                as character: Captain John H. Miller
# 6                            as character: Jim Lovell
# 7                               as character: Joe Fox
# 8                         as character: Paul Edgecomb
# 9                           as Producer in Production
# 10                          as character: Walt Disney
# 11                  as character: Professor G.H. Dorr
# 12                              as character: Himself
# 13                       as character: Robert Langdon
# 14     as character: Older Mike/Narrator (uncredited)
# 15                          as character: Allen Bauer
# 16                       as character: Robert Langdon
# 17                          as Producer in Production
# 18                         as character: Forrest Gump
# 19             as character: Captain Richard Phillips
# 20                        as character: Carl Hanratty
# 21                as Executive Producer in Production
# 22                        as character: Woody (voice)
# 23  as character: Dr. Henry Goose / Hotel Manager ...
# 24                        as character: Woody (voice)
# 25                         as character: Chuck Noland
# 26                         as character: Larry Crowne
# 27                            as character: Mr. White
# 28                     as character: Michael Sullivan
# 29                          as Producer in Production
# 30                          as Producer in Production
# 31                 as character: Joshua "Josh" Baskin
# 32                          as Producer in Production
# 33                      as character: Viktor Navorski
# 34                       as character: Charlie Wilson
# 35                      as character: Himself (voice)
# 36                    as character: Woody Car (voice)
# 37                          as character: Jimmy Dugan
# 38                     as character: James B. Donovan

# %% [markdown]
# ### Find 2 cast poeple. Find the movies in which they both appear (Logical AND)
#
# Here we search for Tom Hanks and Meg Ryan. The All in the Find Connected entity means that find a set which is connected to both the cast people.

# %%
from aperturedb.CommonLibrary import execute_query

q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", ["Tom hanks"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", [ "Meg ryan"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "is_connected_to": {
                "all": [
                {"ref": 1},
                {"ref": 2}
                ]
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"],
                # "group_by_source": True
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

pd.json_normalize(response[2]["FindEntity"]["entities"])
# Out:
#        _uniqueid    budget    id  label  movie_id             name  \
# 0  32.737.483974  65000000  9489  MOVIE      9489  You've got mail
#
#                                             overview  popularity  \
# 0  Book superstore magnate, Joe Fox and independe...   28.540267
#
#                                              tagline            title  \
# 0  Someone you pass on the street may already be ...  You've Got Mail
#
#    vote_average  vote_count
# 0           6.3         838

# %% [markdown]
# ## We can write the same queries in SPARQL.

# %%
from aperturedb.SPARQL import SPARQL
import json


sparql = SPARQL(client, debug=True)
print("namespaces:", json.dumps({k: str(v) for k, v in sparql.namespaces.items()}, indent=2))

print("properties:", json.dumps({sparql.graph.qname(k): str(v)
      for k, v in sparql.properties.items()}, indent=2))

print("connections:", json.dumps({sparql.graph.qname(k): str(v)
      for k, v in sparql.connections.items()}, indent=2))
# Out:
# namespaces: {
#   "t": "http://aperturedb.io/type/",
#   "c": "http://aperturedb.io/connection/",
#   "p": "http://aperturedb.io/property/",
#   "o": "http://aperturedb.io/object/",
#   "knn": "http://aperturedb.io/knn/",
#   "GENRE": "http://aperturedb.io/object/GENRE/",
#   "KEYWORD": "http://aperturedb.io/object/KEYWORD/",
#   "MOVIE": "http://aperturedb.io/object/MOVIE/",
#   "PRODUCTION_COMPANY": "http://aperturedb.io/object/PRODUCTION_COMPANY/",
#   "PROFESSIONAL": "http://aperturedb.io/object/PROFESSIONAL/",
#   "SPOKEN_LANGUAGE": "http://aperturedb.io/object/SPOKEN_LANGUAGE/"
# }
# properties: {
#   "p:id": "{'PROFESSIONAL', 'MOVIE', 'GENRE', 'PRODUCTION_COMPANY', 'KEYWORD'}",
#   "p:label": "{'PROFESSIONAL', 'MOVIE', 'GENRE', 'SPOKEN_LANGUAGE', 'PRODUCTION_COMPANY', 'KEYWORD'}",
#   "p:name": "{'PROFESSIONAL', 'MOVIE', 'GENRE', 'SPOKEN_LANGUAGE', 'PRODUCTION_COMPANY', 'KEYWORD'}",
#   "p:budget": "{'MOVIE'}",
#   "p:movie_id": "{'MOVIE'}",
#   "p:overview": "{'MOVIE'}",
#   "p:popularity": "{'MOVIE'}",
#   "p:tagline": "{'MOVIE'}",
#   "p:title": "{'MOVIE'}",
#   "p:vote_average": "{'MOVIE'}",
#   "p:vote_count": "{'MOVIE'}",
#   "p:gender": "{'PROFESSIONAL'}",
#   "p:iso_639_1": "{'SPOKEN_LANGUAGE'}"
# }
# connections: {
#   "c:CAST": "({'MOVIE'}, {'PROFESSIONAL'})",
#   "c:CREW": "({'MOVIE'}, {'PROFESSIONAL'})",
#   "c:HAS_GENRE": "({'MOVIE'}, {'GENRE'})",
#   "c:HAS_KEYWORD": "({'MOVIE'}, {'KEYWORD'})",
#   "c:HAS_PRODUCTION_COMPANY": "({'MOVIE'}, {'PRODUCTION_COMPANY'})",
#   "c:HAS_SPOKEN_LANGUAGE": "({'MOVIE'}, {'SPOKEN_LANGUAGE'})"
# }

# %% [markdown]
# ### Find all the movies where Tom Hanks as been a part of

# %%
query = """
SELECT  ?title ?pop ?budget
WHERE {
  # ?p p:name "Tom hanks" .
  # ?m c:CAST ?p .
  # ?m p:title ?title ;
    p:popularity ?pop ;
    p:budget ?budget .
}
"""

results = sparql.query(query)
df = sparql.to_dataframe(results)
display(df)
# Out:
#                                 title         pop     budget
# 0   Extremely Loud & Incredibly Close   31.066874   40000000
# 1                        Philadelphia   44.301745   26000000
# 2                         Toy Story 3   59.995418  200000000
# 3                   The Polar Express   47.323228  165000000
# 4                 Saving Private Ryan   76.041867   70000000
# 5                           Apollo 13   68.140214   52000000
# 6                     You've Got Mail   28.540267   65000000
# 7                      The Green Mile  103.698022   60000000
# 8                    Saving Mr. Banks   31.957947   35000000
# 9                     The Ladykillers   23.666229          0
# 10       Who Killed the Electric Car?    5.323184    1000000
# 11                    Angels & Demons   67.447636  150000000
# 12                        Radio Flyer    3.503408   35000000
# 13                             Splash   21.735068    8000000
# 14                  The Da Vinci Code   45.313197  125000000
# 15                       Forrest Gump  138.133331   55000000
# 16                   Captain Phillips   52.786917   55000000
# 17                Catch Me If You Can   73.944049   52000000
# 18                          Toy Story   73.640445   30000000
# 19                        Cloud Atlas   73.872343  102000000
# 20                        Toy Story 2   73.575118   90000000
# 21                          Cast Away   57.739713   90000000
# 22                       Larry Crowne   20.355458   30000000
# 23                 That Thing You Do!   14.885388          0
# 24                  Road to Perdition   49.078546   80000000
# 25                                Big   20.716023   18000000
# 26                       The Terminal   57.753914   60000000
# 27               Charlie Wilson's War   18.700310   75000000
# 28                 The Simpsons Movie   46.875375   75000000
# 29                               Cars   82.643036  120000000
# 30              A League of Their Own   21.661028   40000000
# 31                    Bridge of Spies   48.445978   40000000

# %% [markdown]
# ### Find 2 cast people. Find the movies they have been part of.

# %%
query = """
SELECT  ?title ?pop ?budget
WHERE {
  # ?m c:CAST [p:name "Tom hanks"] , [p:name "Meg ryan"] ;
    p:title ?title ;
    p:popularity ?pop ;
    p:budget ?budget .
}
"""

results = sparql.query(query)
df = sparql.to_dataframe(results)
display(df)
# print(json.dumps(sparql.input_query, indent=2))
# Out:
#              title        pop    budget
# 0  You've Got Mail  28.540267  65000000
