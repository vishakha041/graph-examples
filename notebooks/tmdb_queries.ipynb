# %% [markdown]
# # Querying [tmdb](https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata) movie information from aperturedb.
#
# This notebook will work on an instance of ApertureDB, which can be on the [cloud](https://cloud.aperturedata.io), or running as a [local docker container(s)](https://docs.aperturedata.io/Setup/server/Local)
#
# The dataset is hosted on kaggle, and available via a mlcroissant link.

# %%
# %pip install --quiet mlcroissant pandas dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import all the modules needed

# %%
import pandas as pd
from IPython.display import display


from aperturedb.CommonLibrary import (
    execute_query,
    create_connector
)
from aperturedb.Utils import Utils

# %%
client=create_connector()
utils = Utils(client)
utils.summary()
# Out:
# ================== Summary ==================
# Database: graph-examples-ulrn7q84.farm0000.cloud.aperturedata.io
# Version: 0.18.9
# Status:  0
# Info:    OK
# ------------------ Entities -----------------
# Total entities types:    6
# GENRE
#   Total elements: 20
# I   Number   | id        |        20 (100%)
#     String   | label     |        20 (100%)
#     String   | name      |        20 (100%)
#   ! String   | uniqueid  |        20 (100%)
# KEYWORD
#   Total elements: 9813
# I   Number   | id        |      9813 (100%)
#     String   | label     |      9813 (100%)
#     String   | name      |      9813 (100%)
#   ! String   | uniqueid  |      9813 (100%)
# MOVIE
#   Total elements: 4803
#     Number   | budget        |      4803 (100%)
# I   String   | id            |      4803 (100%)
#     String   | label         |      4803 (100%)
#   ! Number   | movie_id      |      4803 (100%)
#     String   | overview      |      4803 (100%)
#     Number   | popularity    |      4803 (100%)
#     String   | tagline       |      4803 (100%)
#     String   | title         |      4803 (100%)
#   ! String   | uniqueid      |      4803 (100%)
#     Number   | vote_average  |      4803 (100%)
#     Number   | vote_count    |      4803 (100%)
# PRODUCTION_COMPANY
#   Total elements: 5047
# I   Number   | id        |      5047 (100%)
#     String   | label     |      5047 (100%)
#     String   | name      |      5047 (100%)
#   ! String   | uniqueid  |      5047 (100%)
# PROFESSIONAL
#   Total elements: 104842
#     Number   | gender    |    104842 (100%)
# I   Number   | id        |    104842 (100%)
#     String   | label     |    104842 (100%)
#     String   | name      |    104842 (100%)
#   ! String   | uniqueid  |    104842 (100%)
# SPOKEN_LANGUAGE
#   Total elements: 87
# I   String   | iso_639_1  |        87 (100%)
#     String   | label      |        87 (100%)
#     String   | name       |        87 (100%)
#   ! String   | uniqueid   |        87 (100%)
# ---------------- Connections ----------------
# Total connections types: 6
# CAST
#   MOVIE ====> PROFESSIONAL
#   Total elements: 106257
# I   Number   | cast_id    |    106257 (100%)
#     String   | character  |    106257 (100%)
#     String   | name       |    106257 (100%)
#   ! String   | uniqueid   |    106257 (100%)
# CREW
#   MOVIE ====> PROFESSIONAL
#   Total elements: 129581
#   ! String   | credit_id   |    129581 (100%)
#     String   | department  |    129581 (100%)
#     String   | job         |    129581 (100%)
#     String   | name        |    129581 (100%)
#   ! String   | uniqueid    |    129581 (100%)
# HAS_GENRE
#   MOVIE ====> GENRE
#   Total elements: 12160
#     String   | name      |     12160 (100%)
#   ! String   | uniqueid  |     12160 (100%)
# HAS_KEYWORD
#   MOVIE ====> KEYWORD
#   Total elements: 36194
#     String   | name      |     36194 (100%)
#   ! String   | uniqueid  |     36194 (100%)
# HAS_PRODUCTION_COMPANY
#   MOVIE ====> PRODUCTION_COMPANY
#   Total elements: 13677
#     String   | name      |     13677 (100%)
#   ! String   | uniqueid  |     13677 (100%)
# HAS_SPOKEN_LANGUAGE
#   MOVIE ====> SPOKEN_LANGUAGE
#   Total elements: 6937
#     String   | name      |      6937 (100%)
#   ! String   | uniqueid  |      6937 (100%)
# ------------------ Totals -------------------
# Total nodes: 124612
# Total edges: 304806
# =============================================

# %% [markdown]
# ## Query time!
# ### Find all the movies where Tom Hanks as been a part of

# %%
q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints": {
                "name": ["==", "Tom Hanks"]
            },
            "results": {
                "all_properties": True
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "is_connected_to": {
                "ref": 1
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"]
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

display(pd.json_normalize(response[0]["FindEntity"]["entities"]))
display(pd.json_normalize(response[1]["FindEntity"]["entities"]))

movie_ids = [e["movie_id"] for e in response[1]["FindEntity"]["entities"]]
display(movie_ids)
# Out:
#      _uniqueid  gender  id         label       name   uniqueid
# 0  8.11428.742       2  31  PROFESSIONAL  Tom Hanks  Tom hanks
#      _uniqueid     budget      id  label  movie_id  \
# 0    7.329.742   40000000   64685  MOVIE     64685
# 1    7.579.746   26000000    9800  MOVIE      9800
# 2    7.759.750    1000000   13508  MOVIE     13508
# 3    7.827.752   70000000     857  MOVIE       857
# 4    7.834.752   52000000     568  MOVIE       568
# 5    7.837.752   65000000    9489  MOVIE      9489
# 6    7.889.752   60000000     497  MOVIE       497
# 7    7.942.754  200000000   10193  MOVIE     10193
# 8    7.973.754  175000000    2698  MOVIE      2698
# 9    7.990.754  165000000    5255  MOVIE      5255
# 10  7.1220.760   55000000   13600  MOVIE     13600
# 11  7.1284.760   35000000  140823  MOVIE    140823
# 12  7.1295.760          0    5516  MOVIE      5516
# 13  7.1832.772    8000000    2619  MOVIE      2619
# 14  7.2153.778   35000000   20763  MOVIE     20763
# 15  7.2228.780  150000000   13448  MOVIE     13448
# 16  7.2408.784   55000000      13  MOVIE        13
# 17  7.2417.784   55000000  109424  MOVIE    109424
# 18  7.2482.784   52000000     640  MOVIE       640
# 19  7.2485.784   52000000   11631  MOVIE     11631
# 20  7.2804.792          0    9591  MOVIE      9591
# 21  7.2939.794   30000000     862  MOVIE       862
# 22  7.3101.798  125000000     591  MOVIE       591
# 23  7.3193.798  100000000   16523  MOVIE     16523
# 24  7.3806.812   30000000   59861  MOVIE     59861
# 25  7.3897.814  102000000   83542  MOVIE     83542
# 26  7.3939.814   90000000     863  MOVIE       863
# 27  7.3980.814   90000000    8358  MOVIE      8358
# 28  7.4008.818   18000000    2280  MOVIE      2280
# 29  7.4019.818   18000000  302688  MOVIE    302688
# 30  7.4185.820    5000000    8346  MOVIE      8346
# 31  7.4374.824   50000000    9906  MOVIE      9906
# 32  7.4543.832   80000000    4147  MOVIE      4147
# 33  7.4659.840   40000000   11287  MOVIE     11287
# 34  7.4687.840   40000000  296098  MOVIE    296098
# 35  7.4723.880   60000000     594  MOVIE       594
# 36  7.4726.880   75000000    6538  MOVIE      6538
# 37  7.4760.880   75000000      35  MOVIE        35
# 38  7.4768.880  120000000     920  MOVIE       920
#
#                                              overview  popularity  \
# 0   A year after his father's death, Oskar, a trou...   31.066874
# 1   No one would take his case until one man was w...   44.301745
# 2   In 1996, electric cars began to appear on road...    5.323184
# 3   As U.S. troops storm the beaches of Normandy, ...   76.041867
#
# 4                           Apollo 13                          Apollo 13
# 5                     You've Got Mail                    You've got mail
# 6                      The Green Mile                     The green mile
# 7                         Toy Story 3                        Toy story 3
# 8                       Evan Almighty                      Evan almighty
# 9                   The Polar Express                  The polar express
# 10                      City of Ember                      City of ember
# 11                   Saving Mr. Banks                   Saving mr. banks
# 12                    The Ladykillers                    The ladykillers
# 13                             Splash                             Splash
# 14                        Radio Flyer                        Radio flyer
# 15                    Angels & Demons                    Angels & demons
# 16                       Forrest Gump                       Forrest gump
# 17                   Captain Phillips                   Captain phillips
# 18                Catch Me If You Can                Catch me if you can
# 19                         Mamma Mia!                         Mamma mia!
# 20                 That Thing You Do!                 That thing you do!
# 21                          Toy Story                          Toy story
# 22                  The Da Vinci Code                  The da vinci code
# 23          Where the Wild Things Are          Where the wild things are
# 24                       Larry Crowne                       Larry crowne
# 25                        Cloud Atlas                        Cloud atlas
# 26                        Toy Story 2                        Toy story 2
# 27                          Cast Away                          Cast away
# 28                                Big                                Big
# 29         My Big Fat Greek Wedding 2         My big fat greek wedding 2
# 30           My Big Fat Greek Wedding           My big fat greek wedding
# 31                      The Ant Bully                      The ant bully
# 32                  Road to Perdition                  Road to perdition
# 33              A League of Their Own              A league of their own
# 34                    Bridge of Spies                    Bridge of spies
# 35                       The Terminal                       The terminal
# 36               Charlie Wilson's War               Charlie wilson's war
# 37                 The Simpsons Movie                 The simpsons movie
# 38                               Cars                               Cars
#
#     vote_average  vote_count
# 0            6.9         708
# 1            7.6         988
# 2            7.2          59
# 3            7.9        5048
# 4            7.3        1599
# 5            6.3         838
# 6            8.2        4048
# 7            7.6        4597
# 8            5.3        1151
# 9            6.4        1474
# 10           6.2         605
# 11           7.3        1226
# 12           6.0         415
# 13           6.1         321
# 14           6.6          53
# 15           6.5        2129
# 16           8.2        7927
# 17           7.6        2454
# 18           7.7        3795
# 19           6.4        1386
# 20           6.8         225
# 21           7.7        5269
# 22           6.5        2704
# 23           6.4         572
# 24           5.7         359
# 25           6.6        2977
# 26           7.3        3806
# 27           7.5        3218
# 28           6.9         993
# 29           5.5         322
# 30           6.2         671
# 31           5.5         366
# 32           7.3        1077
# 33           6.7         354
# 34           7.2        2583
# 35           7.0        1910
# 36           6.5         338
# 37           6.9        2264
# 38           6.6        3877
# [64685,
#  9800,
#  13508,
#  857,
#  568,
#  9489,
#  497,
#  10193,
#  2698,
#  5255,
#  13600,
#  140823,
#  5516,
#  2619,
#  20763,
#  13448,
#  13,
#  109424,
#  640,
#  11631,
#  9591,
#  862,
#  591,
#  16523,
#  59861,
#  83542,
#  863,
#  8358,
#  2280,
#  302688,
#  8346,
#  9906,
#  4147,
#  11287,
#  296098,
#  594,
#  6538,
#  35,
#  920]

# %% [markdown]
# ### Get more info.
#
# This response from cast and movies entities still misses the character information, because it's been encoded on the properties on connection between the 2. Let's merge that info in and get more richer details about the movies Tom Hanks has been a part of.

# %%
professional = pd.json_normalize(response[1]["FindEntity"]["entities"])

professional_details = []
for p in response[0]["FindEntity"]["entities"]:
    src = p["_uniqueid"]
    for m in response[1]["FindEntity"]["entities"]:
        dst = m["_uniqueid"]
        q = [{
            "FindEntity": {
                "_ref": 1,
                "with_class": "PROFESSIONAL",
                "constraints": {
                    "_uniqueid": ["==", src]
                },
                "results": {
                    "all_properties": True
                }
            }
        },
        {
            "FindEntity": {
                "_ref": 2,
                "is_connected_to": {
                    "ref": 1
                },
                "with_class": "MOVIE",
                "constraints": {
                    "_uniqueid": ["==", dst]
                },
                "results": {
                    "all_properties": True
                }
            }
        },{
            "FindConnection": {
                "src": 2,
                "dst": 1,
                "results": {
                    "all_properties": True
                }
            }
        }]
        _, responsec, _ = execute_query(client, q)
        # print(f"{response=}")

        if responsec[2]["FindConnection"]["returned"] > 0:
            c = responsec[2]["FindConnection"]["connections"][0]
            # print(f"{p['name']} has acted in {m['title']} as {c['character']}")
            # print(f"{p['name']} has contributed in {m['title']}")
            if "character" in c:
                professional_details.append(f"as character: {c['character']}")
            else:
                professional_details.append(f"as {c['job']} in {c['department']}")
            # display(pd.json_normalize(response[3]["FindConnection"]["connections"]))
display(len(professional_details))
professional['details'] = professional_details

display(professional)
# Out:
# 39
#      _uniqueid     budget      id  label  movie_id  \
# 0    7.329.742   40000000   64685  MOVIE     64685
# 1    7.579.746   26000000    9800  MOVIE      9800
# 2    7.759.750    1000000   13508  MOVIE     13508
# 3    7.827.752   70000000     857  MOVIE       857
# 4    7.834.752   52000000     568  MOVIE       568
# 5    7.837.752   65000000    9489  MOVIE      9489
# 6    7.889.752   60000000     497  MOVIE       497
# 7    7.942.754  200000000   10193  MOVIE     10193
# 8    7.973.754  175000000    2698  MOVIE      2698
# 9    7.990.754  165000000    5255  MOVIE      5255
# 10  7.1220.760   55000000   13600  MOVIE     13600
# 11  7.1284.760   35000000  140823  MOVIE    140823
# 12  7.1295.760          0    5516  MOVIE      5516
# 13  7.1832.772    8000000    2619  MOVIE      2619
# 14  7.2153.778   35000000   20763  MOVIE     20763
# 15  7.2228.780  150000000   13448  MOVIE     13448
# 16  7.2408.784   55000000      13  MOVIE        13
# 17  7.2417.784   55000000  109424  MOVIE    109424
# 18  7.2482.784   52000000     640  MOVIE       640
# 19  7.2485.784   52000000   11631  MOVIE     11631
# 20  7.2804.792          0    9591  MOVIE      9591
# 21  7.2939.794   30000000     862  MOVIE       862
# 22  7.3101.798  125000000     591  MOVIE       591
# 23  7.3193.798  100000000   16523  MOVIE     16523
# 24  7.3806.812   30000000   59861  MOVIE     59861
# 25  7.3897.814  102000000   83542  MOVIE     83542
# 26  7.3939.814   90000000     863  MOVIE       863
# 27  7.3980.814   90000000    8358  MOVIE      8358
# 28  7.4008.818   18000000    2280  MOVIE      2280
# 29  7.4019.818   18000000  302688  MOVIE    302688
# 30  7.4185.820    5000000    8346  MOVIE      8346
# 31  7.4374.824   50000000    9906  MOVIE      9906
# 32  7.4543.832   80000000    4147  MOVIE      4147
# 33  7.4659.840   40000000   11287  MOVIE     11287
# 34  7.4687.840   40000000  296098  MOVIE    296098
# 35  7.4723.880   60000000     594  MOVIE       594
# 36  7.4726.880   75000000    6538  MOVIE      6538
# 37  7.4760.880   75000000      35  MOVIE        35
# 38  7.4768.880  120000000     920  MOVIE       920
#
#                                              overview  popularity  \
# 0   A year after his father's death, Oskar, a trou...   31.066874
# 1   No one would take his case until one man was w...   44.301745
# 2   In 1996, electric cars began to appear on road...    5.323184
# 3   As U.S. troops storm the beaches of Normandy, ...   76.041867
#
# 1                        Philadelphia                       Philadelphia
# 2        Who Killed the Electric Car?       Who killed the electric car?
# 3                 Saving Private Ryan                Saving private ryan
# 4                           Apollo 13                          Apollo 13
# 5                     You've Got Mail                    You've got mail
# 6                      The Green Mile                     The green mile
# 7                         Toy Story 3                        Toy story 3
# 8                       Evan Almighty                      Evan almighty
# 9                   The Polar Express                  The polar express
# 10                      City of Ember                      City of ember
# 11                   Saving Mr. Banks                   Saving mr. banks
# 12                    The Ladykillers                    The ladykillers
# 13                             Splash                             Splash
# 14                        Radio Flyer                        Radio flyer
# 15                    Angels & Demons                    Angels & demons
# 16                       Forrest Gump                       Forrest gump
# 17                   Captain Phillips                   Captain phillips
# 18                Catch Me If You Can                Catch me if you can
# 19                         Mamma Mia!                         Mamma mia!
# 20                 That Thing You Do!                 That thing you do!
# 21                          Toy Story                          Toy story
# 22                  The Da Vinci Code                  The da vinci code
# 23          Where the Wild Things Are          Where the wild things are
# 24                       Larry Crowne                       Larry crowne
# 25                        Cloud Atlas                        Cloud atlas
# 26                        Toy Story 2                        Toy story 2
# 27                          Cast Away                          Cast away
# 28                                Big                                Big
# 29         My Big Fat Greek Wedding 2         My big fat greek wedding 2
# 30           My Big Fat Greek Wedding           My big fat greek wedding
# 31                      The Ant Bully                      The ant bully
# 32                  Road to Perdition                  Road to perdition
# 33              A League of Their Own              A league of their own
# 34                    Bridge of Spies                    Bridge of spies
# 35                       The Terminal                       The terminal
# 36               Charlie Wilson's War               Charlie wilson's war
# 37                 The Simpsons Movie                 The simpsons movie
# 38                               Cars                               Cars
#
#     vote_average  vote_count  \
# 0            6.9         708
# 1            7.6         988
# 2            7.2          59
# 3            7.9        5048
# 4            7.3        1599
# 5            6.3         838
# 6            8.2        4048
# 7            7.6        4597
# 8            5.3        1151
# 9            6.4        1474
# 10           6.2         605
# 11           7.3        1226
# 12           6.0         415
# 13           6.1         321
# 14           6.6          53
# 15           6.5        2129
# 16           8.2        7927
# 17           7.6        2454
# 18           7.7        3795
# 19           6.4        1386
# 20           6.8         225
# 21           7.7        5269
# 22           6.5        2704
# 23           6.4         572
# 24           5.7         359
# 25           6.6        2977
# 26           7.3        3806
# 27           7.5        3218
# 28           6.9         993
# 29           5.5         322
# 30           6.2         671
# 31           5.5         366
# 32           7.3        1077
# 33           6.7         354
# 34           7.2        2583
# 35           7.0        1910
# 36           6.5         338
# 37           6.9        2264
# 38           6.6        3877
#
#                                               details
# 0                         as character: Thomas Schell
# 1                        as character: Andrew Beckett
# 2                               as character: Himself
# 3                as character: Captain John H. Miller
# 4                            as character: Jim Lovell
# 5                               as character: Joe Fox
# 6                         as character: Paul Edgecomb
# 7                         as character: Woody (voice)
# 8                 as Executive Producer in Production
# 9   as character: Hero Boy / Father / Conductor / ...
# 10                          as Producer in Production
# 11                          as character: Walt Disney
# 12                  as character: Professor G.H. Dorr
# 13                          as character: Allen Bauer
# 14     as character: Older Mike/Narrator (uncredited)
# 15                       as character: Robert Langdon
# 16                         as character: Forrest Gump
# 17             as character: Captain Richard Phillips
# 18                        as character: Carl Hanratty
# 19                as Executive Producer in Production
# 20                            as character: Mr. White
# 21                        as character: Woody (voice)
# 22                       as character: Robert Langdon
# 23                          as Producer in Production
# 24                         as character: Larry Crowne
# 25  as character: Dr. Henry Goose / Hotel Manager ...
# 26                        as character: Woody (voice)
# 27                         as character: Chuck Noland
# 28                 as character: Joshua "Josh" Baskin
# 29                          as Producer in Production
# 30                          as Producer in Production
# 31                          as Producer in Production
# 32                     as character: Michael Sullivan
# 33                          as character: Jimmy Dugan
# 34                     as character: James B. Donovan
# 35                      as character: Viktor Navorski
# 36                       as character: Charlie Wilson
# 37                      as character: Himself (voice)
# 38                    as character: Woody Car (voice)

# %% [markdown]
# ### Find 2 cast poeple. Find the movies in which they both appear (Logical AND)
#
# Here we search for Tom Hanks and Meg Ryan. The All in the Find Connected entity means that find a set which is connected to both the cast people.

# %%
from aperturedb.CommonLibrary import execute_query

q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", ["Tom Hanks"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", [ "Meg Ryan"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "is_connected_to": {
                "all": [
                {"ref": 1},
                {"ref": 2}
                ]
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"],
                # "group_by_source": True
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

pd.json_normalize(response[2]["FindEntity"]["entities"])
# Out:
#    _uniqueid    budget    id  label  movie_id  \
# 0  7.837.752  65000000  9489  MOVIE      9489
#
#                                             overview  popularity  \
# 0  Book superstore magnate, Joe Fox and independe...   28.540267
#
#                                              tagline            title  \
# 0  Someone you pass on the street may already be ...  You've Got Mail
#
#           uniqueid  vote_average  vote_count
# 0  You've got mail           6.3         838

# %% [markdown]
# ## We can write the same queries in SPARQL.
#
# Trying the above examples (whatever is possible), as sparql does not deal with properties on relations.

# %%
from aperturedb.SPARQL import SPARQL
import json


sparql = SPARQL(client, debug=True)
print("namespaces:", json.dumps({k: str(v) for k, v in sparql.namespaces.items()}, indent=2))

print("properties:", json.dumps({sparql.graph.qname(k): str(v)
      for k, v in sparql.properties.items()}, indent=2))

print("connections:", json.dumps({sparql.graph.qname(k): str(v)
      for k, v in sparql.connections.items()}, indent=2))
# Out:
# namespaces: {
#   "t": "http://aperturedb.io/type/",
#   "c": "http://aperturedb.io/connection/",
#   "p": "http://aperturedb.io/property/",
#   "o": "http://aperturedb.io/object/",
#   "knn": "http://aperturedb.io/knn/",
#   "GENRE": "http://aperturedb.io/object/GENRE/",
#   "KEYWORD": "http://aperturedb.io/object/KEYWORD/",
#   "MOVIE": "http://aperturedb.io/object/MOVIE/",
#   "PRODUCTION_COMPANY": "http://aperturedb.io/object/PRODUCTION_COMPANY/",
#   "PROFESSIONAL": "http://aperturedb.io/object/PROFESSIONAL/",
#   "SPOKEN_LANGUAGE": "http://aperturedb.io/object/SPOKEN_LANGUAGE/"
# }
# properties: {
#   "p:id": "{'KEYWORD', 'MOVIE', 'GENRE', 'PRODUCTION_COMPANY', 'PROFESSIONAL'}",
#   "p:label": "{'SPOKEN_LANGUAGE', 'KEYWORD', 'MOVIE', 'GENRE', 'PRODUCTION_COMPANY', 'PROFESSIONAL'}",
#   "p:name": "{'SPOKEN_LANGUAGE', 'KEYWORD', 'GENRE', 'PRODUCTION_COMPANY', 'PROFESSIONAL'}",
#   "p:uniqueid": "{'SPOKEN_LANGUAGE', 'KEYWORD', 'MOVIE', 'GENRE', 'PRODUCTION_COMPANY', 'PROFESSIONAL'}",
#   "p:budget": "{'MOVIE'}",
#   "p:movie_id": "{'MOVIE'}",
#   "p:overview": "{'MOVIE'}",
#   "p:popularity": "{'MOVIE'}",
#   "p:tagline": "{'MOVIE'}",
#   "p:title": "{'MOVIE'}",
#   "p:vote_average": "{'MOVIE'}",
#   "p:vote_count": "{'MOVIE'}",
#   "p:gender": "{'PROFESSIONAL'}",
#   "p:iso_639_1": "{'SPOKEN_LANGUAGE'}"
# }
# connections: {
#   "c:CAST": "({'MOVIE'}, {'PROFESSIONAL'})",
#   "c:CREW": "({'MOVIE'}, {'PROFESSIONAL'})",
#   "c:HAS_GENRE": "({'MOVIE'}, {'GENRE'})",
#   "c:HAS_KEYWORD": "({'MOVIE'}, {'KEYWORD'})",
#   "c:HAS_PRODUCTION_COMPANY": "({'MOVIE'}, {'PRODUCTION_COMPANY'})",
#   "c:HAS_SPOKEN_LANGUAGE": "({'MOVIE'}, {'SPOKEN_LANGUAGE'})"
# }

# %% [markdown]
# ### Find all the movies where Tom Hanks as been a part of

# %%
query = """
SELECT  ?title ?pop ?budget
WHERE {
  # ?p p:name "Tom Hanks" .
  # ?m c:CAST ?p .
  # ?m p:title ?title ;
    p:popularity ?pop ;
    p:budget ?budget .
}
"""

results = sparql.query(query)
df = sparql.to_dataframe(results)
display(df)
# Out:
#                                 title         pop     budget
# 0   Extremely Loud & Incredibly Close   31.066874   40000000
# 1                        Philadelphia   44.301745   26000000
# 2        Who Killed the Electric Car?    5.323184    1000000
# 3                 Saving Private Ryan   76.041867   70000000
# 4                           Apollo 13   68.140214   52000000
# 5                     You've Got Mail   28.540267   65000000
# 6                      The Green Mile  103.698022   60000000
# 7                         Toy Story 3   59.995418  200000000
# 8                   The Polar Express   47.323228  165000000
# 9                    Saving Mr. Banks   31.957947   35000000
# 10                    The Ladykillers   23.666229          0
# 11                             Splash   21.735068    8000000
# 12                        Radio Flyer    3.503408   35000000
# 13                    Angels & Demons   67.447636  150000000
# 14                       Forrest Gump  138.133331   55000000
# 15                   Captain Phillips   52.786917   55000000
# 16                Catch Me If You Can   73.944049   52000000
# 17                 That Thing You Do!   14.885388          0
# 18                          Toy Story   73.640445   30000000
# 19                  The Da Vinci Code   45.313197  125000000
# 20                       Larry Crowne   20.355458   30000000
# 21                        Cloud Atlas   73.872343  102000000
# 22                        Toy Story 2   73.575118   90000000
# 23                          Cast Away   57.739713   90000000
# 24                                Big   20.716023   18000000
# 25                  Road to Perdition   49.078546   80000000
# 26              A League of Their Own   21.661028   40000000
# 27                    Bridge of Spies   48.445978   40000000
# 28                       The Terminal   57.753914   60000000
# 29               Charlie Wilson's War   18.700310   75000000
# 30                 The Simpsons Movie   46.875375   75000000
# 31                               Cars   82.643036  120000000

# %% [markdown]
# ### Find 2 cast people. Find the movies they have been part of.

# %%
query = """
SELECT  ?title ?pop ?budget
WHERE {
  # ?m c:CAST [p:name "Tom Hanks"] , [p:name "Meg Ryan"] ;
    p:title ?title ;
    p:popularity ?pop ;
    p:budget ?budget .
}
"""

results = sparql.query(query)
df = sparql.to_dataframe(results)
display(df)
# print(json.dumps(sparql.input_query, indent=2))
# Out:
#              title        pop    budget
# 0  You've Got Mail  28.540267  65000000
