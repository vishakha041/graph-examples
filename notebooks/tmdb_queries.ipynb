# %% [markdown]
# # Querying [tmdb](https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata) movie information from aperturedb.
#
# This notebook will work on an instance of ApertureDB, which can be on the [cloud](https://cloud.aperturedata.io), or running as a [local docker container(s)](https://docs.aperturedata.io/Setup/server/Local)
#
# The dataset is hosted on kaggle, and available via a mlcroissant link.

# %%
# %pip install --quiet mlcroissant pandas dotenv
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import all the modules needed

# %%
import pandas as pd
from IPython.display import display


from aperturedb.CommonLibrary import (
    execute_query,
    create_connector
)
from aperturedb.Utils import Utils

# %%
client=create_connector()
utils = Utils(client)
utils.summary()
# Out:
# ================== Summary ==================
# Database: garfield
# Version: 0.18.1
# Status:  0
# Info:    OK
# ------------------ Entities -----------------
# Total entities types:    2
# Movie
#   Total elements: 4803
#     Number   | budget      |      4803 (100%)
# I   String   | id          |      4803 (100%)
#   ! Number   | movie_id    |      4803 (100%)
#     String   | overview    |      4803 (100%)
#     Number   | popularity  |      4803 (100%)
#     String   | title       |      4803 (100%)
# Professional
#   Total elements: 104842
#     Number   | gender  |    104842 (100%)
# I   Number   | id      |    104842 (100%)
#     String   | name    |    104842 (100%)
# ---------------- Connections ----------------
# Total connections types: 2
# CAST
#   Movie ====> Professional
#   Total elements: 106257
# I   Number   | cast_id    |    106257 (100%)
#     String   | character  |    106257 (100%)
# CREW
#   Movie ====> Professional
#   Total elements: 129581
#   ! String   | credit_id   |    129581 (100%)
#     String   | department  |    129581 (100%)
#     String   | job         |    129581 (100%)
# ------------------ Totals -------------------
# Total nodes: 109645
# Total edges: 235838
# =============================================

# %% [markdown]
# ## Query time!
# ### Find all the movies where Tom Hanks as been a part of

# %%
q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints": {
                "name": ["==", "Tom Hanks"]
            },
            "results": {
                "all_properties": True
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "is_connected_to": {
                "ref": 1
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"]
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

display(pd.json_normalize(response[0]["FindEntity"]["entities"]))
display(pd.json_normalize(response[1]["FindEntity"]["entities"]))

movie_ids = [e["movie_id"] for e in response[1]["FindEntity"]["entities"]]
display(movie_ids)
# Out:
#        _uniqueid  gender  id       name
# 0  12.5826.53800       2  31  Tom Hanks
#         _uniqueid     budget      id  movie_id  \
# 0    11.179.53800   26000000    9800      9800
# 1    11.529.53808   40000000   64685     64685
# 2    11.627.53810   70000000     857       857
# 3    11.634.53810   52000000     568       568
# 4    11.637.53810   65000000    9489      9489
# 5    11.689.53810   60000000     497       497
# 6    11.742.53812  200000000   10193     10193
# 7    11.773.53812  175000000    2698      2698
# 8    11.790.53812  165000000    5255      5255
# 9   11.1059.53818    1000000   13508     13508
# 10  11.1320.53824   55000000   13600     13600
# 11  11.1384.53824   35000000  140823    140823
# 12  11.1395.53824          0    5516      5516
# 13  11.1632.53844    8000000    2619      2619
# 14  11.2053.53852   35000000   20763     20763
# 15  11.2228.53856  150000000   13448     13448
# 16  11.2508.53862   55000000      13        13
# 17  11.2517.53862   55000000  109424    109424
# 18  11.2582.53862   52000000     640       640
# 19  11.2585.53862   52000000   11631     11631
# 20  11.2839.53868   30000000     862       862
# 21  11.3104.53874          0    9591      9591
# 22  11.3201.53876  125000000     591       591
# 23  11.3293.53876  100000000   16523     16523
# 24  11.3706.53886   30000000   59861     59861
# 25  11.4084.53892    5000000    8346      8346
# 27                        Toy Story 2
# 28                          Cast Away
# 29                                Big
# 30         My Big Fat Greek Wedding 2
# 31                      The Ant Bully
# 32                  Road to Perdition
# 33              A League of Their Own
# 34                    Bridge of Spies
# 35                       The Terminal
# 36               Charlie Wilson's War
# 37                 The Simpsons Movie
# 38                               Cars
# [9800,
#  64685,
#  857,
#  568,
#  9489,
#  497,
#  10193,
#  2698,
#  5255,
#  13508,
#  13600,
#  140823,
#  5516,
#  2619,
#  20763,
#  13448,
#  13,
#  109424,
#  640,
#  11631,
#  862,
#  9591,
#  591,
#  16523,
#  59861,
#  8346,
#  83542,
#  863,
#  8358,
#  2280,
#  302688,
#  9906,
#  4147,
#  11287,
#  296098,
#  594,
#  6538,
#  35,
#  920]

# %% [markdown]
# ### Get more info.
#
# This response from cast and movies entities still misses the character information, because it's been encoded on the properties on connection between the 2. Let's merge that info in and get more richer details about the movies Tom Hanks has been a part of.

# %%
professional = pd.json_normalize(response[1]["FindEntity"]["entities"])

professional_details = []
for p in response[0]["FindEntity"]["entities"]:
    src = p["_uniqueid"]
    for m in response[1]["FindEntity"]["entities"]:
        dst = m["_uniqueid"]
        q = [{
            "FindEntity": {
                "_ref": 1,
                "with_class": "PROFESSIONAL",
                "constraints": {
                    "_uniqueid": ["==", src]
                },
                "results": {
                    "all_properties": True
                }
            }
        },
        {
            "FindEntity": {
                "_ref": 2,
                "is_connected_to": {
                    "ref": 1
                },
                "with_class": "MOVIE",
                "constraints": {
                    "_uniqueid": ["==", dst]
                },
                "results": {
                    "all_properties": True
                }
            }
        },{
            "FindConnection": {
                "src": 2,
                "dst": 1,
                "results": {
                    "all_properties": True
                }
            }
        }]
        _, responsec, _ = execute_query(client, q)
        # print(f"{response=}")

        if responsec[2]["FindConnection"]["returned"] > 0:
            c = responsec[2]["FindConnection"]["connections"][0]
            # print(f"{p['name']} has acted in {m['title']} as {c['character']}")
            # print(f"{p['name']} has contributed in {m['title']}")
            if "character" in c:
                professional_details.append(f"as character: {c['character']}")
            else:
                professional_details.append(f"as {c['job']} in {c['department']}")
            # display(pd.json_normalize(response[3]["FindConnection"]["connections"]))
display(len(professional_details))
professional['details'] = professional_details

display(professional)
# Out:
# 39
#         _uniqueid     budget      id  movie_id  \
# 0    11.179.53800   26000000    9800      9800
# 1    11.529.53808   40000000   64685     64685
# 2    11.627.53810   70000000     857       857
# 3    11.634.53810   52000000     568       568
# 4    11.637.53810   65000000    9489      9489
# 5    11.689.53810   60000000     497       497
# 6    11.742.53812  200000000   10193     10193
# 7    11.773.53812  175000000    2698      2698
# 8    11.790.53812  165000000    5255      5255
# 9   11.1059.53818    1000000   13508     13508
# 10  11.1320.53824   55000000   13600     13600
# 11  11.1384.53824   35000000  140823    140823
# 12  11.1395.53824          0    5516      5516
# 13  11.1632.53844    8000000    2619      2619
# 14  11.2053.53852   35000000   20763     20763
# 15  11.2228.53856  150000000   13448     13448
# 16  11.2508.53862   55000000      13        13
# 17  11.2517.53862   55000000  109424    109424
# 18  11.2582.53862   52000000     640       640
# 19  11.2585.53862   52000000   11631     11631
# 20  11.2839.53868   30000000     862       862
# 21  11.3104.53874          0    9591      9591
# 9        Who Killed the Electric Car?
# 10                      City of Ember
# 11                   Saving Mr. Banks
# 12                    The Ladykillers
# 13                             Splash
# 14                        Radio Flyer
# 15                    Angels & Demons
# 16                       Forrest Gump
# 17                   Captain Phillips
# 18                Catch Me If You Can
# 19                         Mamma Mia!
# 20                          Toy Story
# 21                 That Thing You Do!
# 22                  The Da Vinci Code
# 23          Where the Wild Things Are
# 24                       Larry Crowne
# 25           My Big Fat Greek Wedding
# 26                        Cloud Atlas
# 27                        Toy Story 2
# 28                          Cast Away
# 29                                Big
# 30         My Big Fat Greek Wedding 2
# 31                      The Ant Bully
# 32                  Road to Perdition
# 33              A League of Their Own
# 34                    Bridge of Spies
# 35                       The Terminal
# 36               Charlie Wilson's War
# 37                 The Simpsons Movie
# 38                               Cars
#
#                                               details
# 0                        as character: Andrew Beckett
# 1                         as character: Thomas Schell
# 2                as character: Captain John H. Miller
# 3                            as character: Jim Lovell
# 4                               as character: Joe Fox
# 5                         as character: Paul Edgecomb
# 6                         as character: Woody (voice)
# 7                 as Executive Producer in Production
# 8   as character: Hero Boy / Father / Conductor / ...
# 9                               as character: Himself
# 10                          as Producer in Production
# 11                          as character: Walt Disney
# 12                  as character: Professor G.H. Dorr
# 13                          as character: Allen Bauer
# 14     as character: Older Mike/Narrator (uncredited)
# 15                       as character: Robert Langdon
# 16                         as character: Forrest Gump
# 17             as character: Captain Richard Phillips
# 18                        as character: Carl Hanratty
# 19                as Executive Producer in Production
# 20                        as character: Woody (voice)
# 21                            as character: Mr. White
# 22                       as character: Robert Langdon
# 23                          as Producer in Production
# 24                         as character: Larry Crowne
# 25                          as Producer in Production
# 26  as character: Dr. Henry Goose / Hotel Manager ...
# 27                        as character: Woody (voice)
# 28                         as character: Chuck Noland
# 29                 as character: Joshua "Josh" Baskin
# 30                          as Producer in Production
# 31                          as Producer in Production
# 32                     as character: Michael Sullivan
# 33                          as character: Jimmy Dugan
# 34                     as character: James B. Donovan
# 35                      as character: Viktor Navorski
# 36                       as character: Charlie Wilson
# 37                      as character: Himself (voice)
# 38                    as character: Woody Car (voice)

# %% [markdown]
# ### Find 2 cast poeple. Find the movies in which they both appear (Logical AND)
#
# Here we search for Tom Hanks and Meg Ryan. The All in the Find Connected entity means that find a set which is connected to both the cast people.

# %%
from aperturedb.CommonLibrary import execute_query

q = [
    {
        "FindEntity": {
            "_ref": 1,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", ["Tom Hanks"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "_ref": 2,
            "with_class": "PROFESSIONAL",
            "constraints":{
                "name": ["in", [ "Meg Ryan"]]
            },
            "results": {
                "all_properties": True
                # "list": ["name", "_uniqueid"]
            }
        }
    },
    {
        "FindEntity": {
            "is_connected_to": {
                "all": [
                {"ref": 1},
                {"ref": 2}
                ]
            },
            "with_class": "MOVIE",
            "results": {
                # "list": ["id", "title"],
                # "group_by_source": True
                "all_properties": True
            }
        }
    }
]

_, response, _ = execute_query(client, q)

pd.json_normalize(response[2]["FindEntity"]["entities"])
# Out:
#       _uniqueid    budget    id  movie_id  \
# 0  11.637.53810  65000000  9489      9489
#
#                                             overview  popularity  \
# 0  Book superstore magnate, Joe Fox and independe...   28.540267
#
#              title
# 0  You've Got Mail
